# %%
import pandas as pd

df = pd.read_csv("D:\\GITHUB\\Summer-2025-ECE-597-Group11\\data\\sensitive_my_email\\yckemail.csv")

# %%
df
# Out:
#                                                Subject  \
# 0    [Engn-announce] Associate Dean Research Candid...
# 1    RE: MADS Course Registration and Scheduling - ...
# 2    RE: 2025 Summer General Bursary application - ...
# 3    Spring 2025 ECE 591 A01 (20951) - Announcement...
# 4                                    Re: AI Q#1 review
# ..                                                 ...
# 321                UVic Orientation event registration
# 322                                                NaN
# 323  Fwd: MADS Course Registration Information - 20...
# 324    Your ONECard Photo Has Been Reviewed and Denied
# 325                                           Re: test
#
#                                                   Body  \
# 0    Dear Faculty, Staff, and Graduate Students,\r\...
# 1    Hi Chengkai,\r\n\r\n \r\n\r\nYes, this looks g...
# 2    Hello Chengkai,\r\n\r\n \r\n\r\nYour bursary a...
# 3    \r\nSpring 2025 ECE 591 A01 (20951) - Announce...
# ...
